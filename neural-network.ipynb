# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import 
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
seed = 5
np.random.seed(seed)

#Načítanie datasetu
dataset = pd.read_csv('dataset_demografic_statistics.csv', delimiter=',')

# %%
X = dataset.loc[:235, dataset.columns != "COUNT PARTICIPANTS"].values
Y = dataset.loc[:235,"COUNT PARTICIPANTS"].values

#rozdelenie dát na testovacie a trénovacie v pomere 67% a 33%
(X_train, X_test, Y_train, Y_test) = train_test_split(X, Y, test_size=0.33, random_state=seed)

# %%
#vytvorenie modelu NS
model = Sequential()

model.add(Dense(45,input_shape=(45,),activation="relu"))
model.add(Dense(1,activation="relu"))
model.compile(loss="mean_squared_error",optimizer="Adamax",metrics=["accuracy"])

model.summary()

history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=1000)

ypred = model.predict(X_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 45)                2070
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 46
# ...
# Total params: 2,116
# Trainable params: 2,116
# Non-trainable params: 0
# _________________________________________________________________
# Train on 158 samples, validate on 78 samples
# Epoch 1/1000
# 158/158 [==============================] - 0s - loss: 2614.2595 - acc: 0.5253 - val_loss: 1291.6026 - val_acc: 0.6154
# Epoch 2/1000
# 158/158 [==============================] - 0s - loss: 2614.2595 - acc: 0.5253 - val_loss: 1291.6026 - val_acc: 0.6154
# Epoch 3/1000
# 158/158 [==============================] - 0s - loss: 2614.2595 - acc: 0.5253 - val_loss: 1291.6026 - val_acc: 0.6154
# Epoch 4/1000
# ...

# %%
#vypisanie dosiahnutych vysledkov testovacich a trenovacich dat
testModel = model.evaluate(X_test,Y_test)
print("\accuracy: %.2f%%" % (testModel[1]*100))

trainModel = model.evaluate(X_train,Y_train)
print("\accuracy: %.2f%%" % (trainModel[1]*100))
# Out:
# ...
#  32/158 [=====>........................] - ETA: 0sccuracy: 52.53%

# %%
print(history.history.keys())
# Out:
# dict_keys(['acc', 'val_acc', 'val_loss', 'loss'])

# %%
#vykreslenie grafu accuracy modelu
plt.plot(history.history['acc'])
plt.title('ACCURACY MODEL')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

plt.plot(history.history['val_acc'])
plt.title('VALIDATION ACCURACY MODEL')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
#vykreslenie dát loss modelu
plt.plot(history.history['loss'])
plt.title('LOSS MODEL')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

plt.plot(history.history['val_loss'])
plt.title('VALIDATION LOSS MODEL')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(Y)

# %%
import seaborn as sns
#vykreslenie dát z datasetu
sns.set(color_codes=True)
sns.jointplot(x="COUNT PARTICIPANTS",y="JURISDICTION NAME", data=dataset);
